# %%
import pandas as pd

# %%
screened_df = pd.read_csv("merge/26_09_25_first_screening_v2.csv", )
# load with compatible encoding
og_df = pd.read_csv("merge/openalex_export.csv", on_bad_lines="skip", encoding="ISO-8859-1")

# %%
screened_df.head()
# Out:
#                                                title  \
# 0  Cognitive digital twin-based Internet of Robot...
# 1  Towards autonomous system: flexible modular pr...
# 2  SciAgents: Automating Scientific Discovery Thr...
# 3  A Large Language Model-based multi-agent manuf...
# 4  Automating alloy design and discovery with phy...
#
#                          doi  inclusion  \
# 0           10.24136/eq.3131          1
# 1  10.48550/ARXIV.2304.14721          1
# 2     10.1002/adma.202413523          1
# 3  10.48550/ARXIV.2405.16887          1
# 4    10.1073/pnas.2414074122          1
#
#                                            reasoning
# 0  The title and fulltext of the paper explicitly...
# 1  1) The article explicitly focuses on Large Lan...
# 2  The article discusses a multi-agent system, Sc...
# 3  The paper 'A Large Language Model-based multi-...
# 4  The paper is excluded because, although it men...

# %%
og_df.head()
# Out:
#                                                ï»¿id  \
# 0                   https://openalex.org/W4387567460
# 1                   https://openalex.org/W4405104323
# 2                   https://openalex.org/W4390824394
# 3                   https://openalex.org/W4402917435
# 4  |Zdenk Caha|Roman Bla~ek|Erika Kovalová|Marek...
#
#                                                  doi  \
# 0    https://doi.org/10.1109/etfa54631.2023.10275362
# 1     https://doi.org/10.1109/sdf63218.2024.10773919
# 2   https://doi.org/10.1021/acsengineeringau.3c00058
# 3                   https://doi.org/10.24136/eq.3131
# 4  https://orcid.org/0000-0002-3422-6310|https://...
#
#                                                title  \
# 0  Towards autonomous system: flexible modular pr...
# 1  A Hybrid AI Framework Integrating Ontology Lea...
# 2  Generative Retrieval-Augmented Ontologic Graph...
# 3  Cognitive digital twin-based Internet of Robot...
# ...
